# %%
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv("/WITHOUT_LANG.csv")

# %%
dataset = dataset.dropna()

# %%
dataset.tail()
# Out:
#       Entity  Christians   Muslims  Unaffiliated    Hindus  Buddhists  \
# 136  Finland    0.784749  0.007300      0.186150  0.000912   0.000912
# 137   Norway    0.797633  0.034680      0.094406  0.003853   0.005780
# 138  Iceland    0.906180  0.015103      0.030206  0.015103   0.015103
# 139   Canada    0.656832  0.019870      0.225287  0.013153   0.007836
# 140   Russia    0.724070  0.098778      0.160229  0.000207   0.001175
#
#      folkReligions  otherReligions      Jews  Population  Temperature    GII  \
# 136       0.000912        0.000912  0.000912     5479461         1.55  0.056
# 137       0.000963        0.001927  0.000963     5190356         1.50  0.053
# 138       0.015103        0.015103  0.015103      331060        -0.70  0.051
# 139       0.010915        0.008396  0.009795    35732126        -5.10  0.098
# 140       0.002143        0.000035  0.001590   144668389        -5.35  0.271
#
#        HDI   POL  INTERNET  PRECIPITATION
# ...

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[['Christians', 'Muslims', 'Unaffiliated', 'Hindus', 'Buddhists', 'folkReligions', 'otherReligions', 'Jews', 'Population', 'Temperature', 'GII', 'HDI', 'POL', 'INTERNET', 'PRECIPITATION']], diag_kind='kde')
